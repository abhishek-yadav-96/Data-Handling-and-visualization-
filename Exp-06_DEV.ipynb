# %% [markdown]
# # EXP_6

# %%
#3049

import matplotlib.pyplot as plt
import pandas as pd
seattle_weather =pd.read_csv("seattle_weather1.csv")
austin_weather=pd.read_csv("austin_weather1.csv")

fig,ax = plt.subplots()
plt.show()

# %%
#3049

seattle_weather
# Out:
#     MLY-PRCP-NORMAL  MLY-TAVG-NORMAL MONTH
# 0              2.20             49.2   Jan
# 1              2.31             52.1   Feb
# 2              2.78             59.2   Mar
# 3              2.27             67.3   Apr
# 4              4.05             75.2   May
# 5              4.63             81.0   Jun
# 6              2.44             83.4   Jul
# 7              2.03             83.7   Aug
# 8              2.54             77.8   Sep
# 9              4.24             69.0   Oct
# 10             2.94             58.4   Nov
# 11             2.21             50.4   Dec

# %%
fig,ax = plt.subplots()
ax.scatter(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"])
plt.show()

# %%
#3049

fig,ax = plt.subplots()
ax.plot(austin_weather["MLY-PRCP-NORMAL"],austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"])
plt.show()

# %%
#3049

fig,ax = plt.subplots()
ax.plot(austin_weather["MLY-PRCP-NORMAL"],austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"],marker='o')
plt.show()

# %%
#3049

fig,ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"],marker='v')
plt.show()
plt.savefig('abc.png')

# %%
fig,ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"],marker='o',linestyle='--')
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"],marker='o',linestyle='--',color='r')
plt.show()

# %%
fig,ax = plt.subplots()
ax.set_title("seattle_weather")
ax.plot(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"],marker='o',linestyle='--',color='y')

# %%
fig,ax = plt.subplots()
ax.set_title("seattle_weather")
ax.plot(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"],marker='o',linestyle='',color='c')
plt.show()

# %%
fig,ax = plt.subplots(3,2)
